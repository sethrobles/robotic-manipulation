# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# cd /work
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting ipywidgets==8.1.7 (from -r ./requirements.txt (line 1))
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting matplotlib==3.10.3 (from -r ./requirements.txt (line 5))
#   Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy==1.26.4 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from -r ./requirements.txt (line 6)) (1.26.4)
# Collecting pydot==4.0.1 (from -r ./requirements.txt (line 7))
#   Downloading pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting PyYAML==6.0.2 (from -r ./requirements.txt (line 8))
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (8.12.3)
# Requirement already satisfied: traitlets>=4.3.1 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets==8.1.7->-r ./requirements.txt (line 1))
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets==8.1.7->-r ./requirements.txt (line 1))
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (24.1)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from matplotlib==3.10.3->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: backcall in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: decorator in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: pickleshare in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: six>=1.5 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.10.3->-r ./requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /toolkit-cache/0.2.30/python3.12/kernel-libs/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7->-r ./requirements.txt (line 1)) (0.2.3)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 5.5 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 80.0 MB/s eta 0:00:00
# Downloading pydot-4.0.1-py3-none-any.whl (37 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 67.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 37.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 92.4 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, PyYAML, pydot, jupyterlab_widgets, matplotlib, ipywidgets
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.6
#     Uninstalling matplotlib-3.10.6:
#       Successfully uninstalled matplotlib-3.10.6
# Successfully installed PyYAML-6.0.2 ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 matplotlib-3.10.3 pydot-4.0.1 widgetsnbextension-4.0.14

# %%
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "check"], cwd="/work")
# Out:
# No broken requirements found.
# 0

# %%
# %%bash
# /opt/drake/share/drake/setup/deepnote/install_nginx
# Out:
#  * Starting nginx nginx
#    ...done.
